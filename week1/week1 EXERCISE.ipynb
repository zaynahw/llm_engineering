# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports

import os
import json
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from scraper import fetch_website_links, fetch_website_contents
from openai import OpenAI

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment

load_dotenv(override=True)
openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

# %%
# here is the question; type over this to ask something new
system_prompt = """
You are a helpful assistant that helps answer user question. These might include code snippets, general explanations, or 
anything else that might be helpful to the user. If the user asks you to explain a piece of code, please do so in a clear and concise manner. 
If the user asks you to write a piece of code, please do so with clear comments and explanations. Real world examples and anologies are always helpful 
when explaining complex concepts, so please use them whenever relevant.
"""

question = """
Please explain what this code does and why:
response = ""
dispay_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    response += chunk.choices[0].delta.content or ' '
    update_display(Markdown(response), display_id=dispay_handle.display_id)
"""

# %%
# implement llama

stream = openai.chat.completions.create(
    model = MODEL_LLAMA,
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": question}
    ],
    stream = True
)

response = ""
dispay_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    response += chunk.choices[0].delta.content or ' '
    update_display(Markdown(response), display_id=dispay_handle.display_id)
# Out:
# **Code Breakdown: Real-time Response Display**
#
# This code snippet generates a real-time response to user input, utilizing Markdown formatting for readability. Let's break it down:
#
# ### Overview
#
# 1. The code starts by initializing an empty string `response` to store the user's input with any formatting applied.
# 2. It creates a display handle using the `display` function from the Pandas library (`dispaly_handle = display(Markdown(""), display_id=True)`). This will render the formatted text in a Jupyter Notebook environment.
# 3. The code then iterates over `stream`, which is assumed to be an iterable containing chunks of user input (e.g., text responses).
# 4. For each chunk:
#    - It takes the first choice (`chunk.choices[0]`) from the stream and extracts its contents as Markdown text using `.delta.content`.
#    - If the content is not empty, it appends it to the `response` string.
# ...
